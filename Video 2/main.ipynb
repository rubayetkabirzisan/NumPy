# %%
# %timeit [j**4 for j in range(1,9)]

import numpy as np
# %timeit np.arange(1,9)**4
# Out:
# 844 ns ± 116 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# 3.87 μs ± 668 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
